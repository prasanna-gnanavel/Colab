# %%
print ("I AM ANWITA  I WOULD LIKE TO KNOW HOW TO PLAY VIDIO GAME IN LAPTOP")
# Out:
# I AM ANWITA  I WOULD LIKE TO KNOW HOW TO PLAY VIDIO GAME IN LAPTOP

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 (default, Nov  7 2019, 10:44:02)
# [GCC 8.3.0]

# %%
a="Trued"
a
type(a)
# Out:
# str

# %%
a=2.0000000000000000000000000000000000001
b=2
a==b
type(a)
# Out:
# float

# %%
data=[1,2,3]
data
# Out:
# [1, 2, 3]

# %%
a=2
def foo(a):
  a=[2,3,2]
  return a



foo(2)
# Out:
# [2, 3, 2]

# %%
print(' w world '.strip())
print(' w world '.rstrip())
# Out:
# w world
#  w world

# %%
x=list('hello machi prasanna')
x.count('a')
print(x)
type(x)
a=(1,2)
type(a)
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'm', 'a', 'c', 'h', 'i', ' ', 'p', 'r', 'a', 's', 'a', 'n', 'n', 'a']
# tuple

# %%
office={'prsanna':148695, 'nit':148698}
print(office)
type(office)
# Out:
# {'prsanna': 148695, 'nit': 148698}
# dict

# %%
import numpy as np


a=([1,2,3],[1,23,2])

b=np.ones((2,2),dtype=np.int8)

# %%
a = np.arrange(10).reshape(5,2)
print (a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-e778d33ba783> in <module>()
#       1 import numpy as np
# ----> 2 a = np.arrange(10).reshape(5,2)
#       3 print (a)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import pandas as pd



s=pd.Series([2,3,3])
s
# Out:
# 0    2
# 1    3
# 2    3
# dtype: int64

# %%
s=pd.Series([2,3,3],index=['a','b','c'])
s
# Out:
# a    2
# b    3
# c    3
# dtype: int64
