# %% [markdown]
# # Lab session 6: association analysis

# %% [markdown]
# ## Introduction
#
# The purpose of this lab session is to provide you with an opportunity to gain experience in **association analysis** using typical Python libraries.
#
# This session starts with a tutorial that uses examples to introduce you to the practical knowledge that you will need for the corresponding assignment. We highly recommend that you read the following tutorials if you need a gentler introduction to the libraries that we use:
# - [Mlxtend: Apriori](http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
# - [Numpy quickstart tutorial](https://numpy.org/devdocs/user/quickstart.html)
# - [Numpy: basic broadcasting](https://numpy.org/doc/stable/user/basics.broadcasting.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
# - [Matplotlib](https://matplotlib.org/tutorials/introductory/pyplot.html)
# - [Seaborn](https://seaborn.pydata.org/tutorial/relational.html)
# - [Scikit-learn](https://scikit-learn.org/stable/tutorial/basic/tutorial.html)

# %% [markdown]
# ## Submission instructions
#
# - The last section of this notebook includes the second part of the assessed assignment for day 3.
# - There will be 4 assessed assignments. Each assignment corresponds to 10% of your final grade.
# - The exam corresponds to the remaining 60% of your final grade.
# - **PLAGIARISM** <ins>leads to irreversible non-negotiable failure in the module</ins> (if you are unsure about what constitutes plagiarism, please ask).
# - The deadline for submitting each assignment is defined on QM+.
# - Penalties for late submissions will be applied in accordance with the School policy. The submission cut-off date is 7 days after the deadline.
# - You should submit a **report** with your solutions to the assignment included in the last section of this notebook. The report should be a single **pdf** file. Other formats (such as doc, docx, or ipynb) are **not** acceptable.
# - The report should be excellently organized and identified with your name, student number, assignment number, and module identifier. When applicable, question numbers should precede the corresponding answers.
# - Please name your report file according to the following convention: Assignment[Number]-[Student Name]-[Student Number].pdf
# - Submissions should be made through QM+. Submissions by e-mail will be ignored.
# - Please always check whether the report file was uploaded correctly to QM+.
# - Cases of **extenuating circumstances** have to go through the proper procedure in accordance with the School policy. Only cases approved by the School in due time will be considered.

# %% [markdown]
# ## 1. Frequent itemsets

# %% [markdown]
# In order to present functionalities for association analysis in Python, we adapt an example from the ``mlxtend`` documentation.
#
# Consider a dataset composed of five transactions. This dataset is represented by a list of five elements, each of which is a list of items bought during a trip to a supermarket.

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],     
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]
type(dataset)
# Out:
# list

# %% [markdown]
# The library ``mlxtend`` requires that each transaction is represented by a binary vector where each element indicates the presence or absence of a specific item.
#
# The method ``TransactionEncoder.fit_transform`` can be used to convert the dataset created above into this expected format. This method returns a binary matrix (numpy array) where each transaction corresponds to a row and each column corresponds to an item.

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit_transform(dataset)
print(te_ary)
# Out:
# [[False False False  True False  True  True  True  True False  True]
#  [False False  True  True False  True False  True  True False  True]
#  [ True False False  True False  True  True False False False False]
#  [False  True False False False  True  True False False  True  True]
#  [False  True False  True  True  True False False  True False False]]

# %%
type(te_ary)
# Out:
# numpy.ndarray

# %% [markdown]
# The item corresponding to each column is stored by the ``TransactionEncoder`` object in a variable called ``columns_``. This variable can be used to create a ``DataFrame`` that conveniently represents the transaction dataset.

# %%
import pandas as pd

df = pd.DataFrame(te_ary, columns=te.columns_)
display(df)
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  ...   Milk  Nutmeg  Onion  Unicorn  Yogurt
# 0  False  False  False   True      False  ...   True    True   True    False    True
# 1  False  False   True   True      False  ...  False    True   True    False    True
# 2   True  False  False   True      False  ...   True   False  False    False   False
# 3  False   True  False  False      False  ...   True   False  False     True    True
# 4  False   True  False   True       True  ...  False   False   True    False   False
#
# [5 rows x 11 columns]

# %% [markdown]
# The ``mlxtend`` function ``apriori`` receives a ``DataFrame`` that represents a transaction dataset and a parameter that specifies the support threshold. This function returns a ``DataFrame`` that contains one row for each frequent itemset. Each row contains a python ``frozenset`` that represents the itemset (by column indices) and a number that represents the support of this itemset.

# %%
from mlxtend.frequent_patterns import apriori
pd.set_option('display.max_rows', 500)

frequent_itemsets = apriori(df, min_support=0.2)
display(frequent_itemsets)

itemset = frequent_itemsets.loc[5]
print('Itemset: {0}. Support: {1}.'.format(itemset['itemsets'], itemset['support']))
# Out:
#      support             itemsets
# 0        0.2                  (0)
# 1        0.4                  (1)
# 2        0.2                  (2)
# 3        0.8                  (3)
# 4        0.2                  (4)
# 5        1.0                  (5)
# 6        0.6                  (6)
# 7        0.4                  (7)
# 8        0.6                  (8)
# 9        0.2                  (9)
# 10       0.6                 (10)
# 11       0.2               (0, 3)
# 12       0.2               (0, 5)
# 13       0.2               (0, 6)
# 14       0.2               (1, 3)
# 15       0.2               (1, 4)
# 16       0.4               (1, 5)
# 17       0.2               (1, 6)
# 18       0.2               (8, 1)
# 19       0.2               (1, 9)
# 20       0.2              (1, 10)
# 21       0.2               (2, 3)
# 22       0.2               (2, 5)
# 23       0.2               (2, 7)
# 24       0.2               (8, 2)
# 25       0.2              (2, 10)
# 26       0.2               (3, 4)
# 27       0.8               (3, 5)
# 28       0.4               (3, 6)
# 29       0.4               (3, 7)
# 30       0.6               (8, 3)
# 31       0.4              (10, 3)
# 32       0.2               (4, 5)
# 33       0.2               (8, 4)
# 34       0.6               (5, 6)
# 35       0.4               (5, 7)
# 36       0.6               (8, 5)
# 37       0.2               (9, 5)
# 38       0.6              (10, 5)
# 39       0.2               (6, 7)
# 40       0.2               (8, 6)
# 41       0.2               (9, 6)
# 42       0.4              (10, 6)
# 43       0.4               (8, 7)
# 44       0.4              (10, 7)
# 45       0.4              (8, 10)
# 46       0.2              (9, 10)
# 47       0.2            (0, 3, 5)
# 48       0.2            (0, 3, 6)
# 49       0.2            (0, 5, 6)
# 50       0.2            (1, 3, 4)
# 51       0.2            (1, 3, 5)
# 52       0.2            (8, 1, 3)
# 53       0.2            (1, 4, 5)
# 54       0.2            (8, 1, 4)
# 55       0.2            (1, 5, 6)
# 56       0.2            (8, 1, 5)
# 57       0.2            (1, 5, 9)
# 58       0.2           (1, 10, 5)
# 59       0.2            (1, 6, 9)
# 60       0.2           (1, 10, 6)
# 61       0.2           (1, 10, 9)
# 62       0.2            (2, 3, 5)
# 63       0.2            (2, 3, 7)
# 64       0.2            (8, 2, 3)
# 65       0.2           (10, 2, 3)
# 66       0.2            (2, 5, 7)
# 67       0.2            (8, 2, 5)
# 68       0.2           (2, 10, 5)
# 69       0.2            (8, 2, 7)
# 70       0.2           (2, 10, 7)
# 71       0.2           (8, 2, 10)
# 72       0.2            (3, 4, 5)
# 73       0.2            (8, 3, 4)
# 74       0.4            (3, 5, 6)
# 75       0.4            (3, 5, 7)
# 76       0.6            (8, 3, 5)
# 77       0.4           (10, 3, 5)
# 78       0.2            (3, 6, 7)
# 79       0.2            (8, 3, 6)
# 80       0.2           (10, 3, 6)
# 81       0.4            (8, 3, 7)
# 82       0.4           (10, 3, 7)
# 83       0.4           (8, 10, 3)
# 84       0.2            (8, 4, 5)
# 85       0.2            (5, 6, 7)
# 86       0.2            (8, 5, 6)
# 87       0.2            (9, 5, 6)
# 88       0.4           (10, 5, 6)
# 89       0.4            (8, 5, 7)
# 90       0.4           (10, 5, 7)
# 91       0.4           (8, 10, 5)
# 92       0.2           (9, 10, 5)
# 93       0.2            (8, 6, 7)
# 94       0.2           (10, 6, 7)
# 95       0.2           (8, 10, 6)
# 96       0.2           (9, 10, 6)
# 97       0.4           (8, 10, 7)
# 98       0.2         (0, 3, 5, 6)
# 99       0.2         (1, 3, 4, 5)
# 100      0.2         (8, 1, 3, 4)
# 101      0.2         (8, 1, 3, 5)
# 102      0.2         (8, 1, 4, 5)
# 103      0.2         (1, 5, 6, 9)
# 104      0.2        (1, 10, 5, 6)
# 105      0.2        (1, 10, 5, 9)
# 106      0.2        (1, 10, 6, 9)
# 107      0.2         (2, 3, 5, 7)
# 108      0.2         (8, 2, 3, 5)
# 109      0.2        (10, 2, 3, 5)
# 110      0.2         (8, 2, 3, 7)
# 111      0.2        (10, 2, 3, 7)
# 112      0.2        (8, 10, 2, 3)
# 113      0.2         (8, 2, 5, 7)
# 114      0.2        (2, 10, 5, 7)
# 115      0.2        (8, 2, 10, 5)
# 116      0.2        (8, 2, 10, 7)
# 117      0.2         (8, 3, 4, 5)
# 118      0.2         (3, 5, 6, 7)
# 119      0.2         (8, 3, 5, 6)
# 120      0.2        (10, 3, 5, 6)
# 121      0.4         (8, 3, 5, 7)
# 122      0.4        (10, 3, 5, 7)
# 123      0.4        (8, 10, 3, 5)
# 124      0.2         (8, 3, 6, 7)
# 125      0.2        (10, 3, 6, 7)
# 126      0.2        (8, 10, 3, 6)
# 127      0.4        (8, 10, 3, 7)
# 128      0.2         (8, 5, 6, 7)
# 129      0.2        (10, 5, 6, 7)
# 130      0.2        (8, 10, 5, 6)
# 131      0.2        (9, 10, 5, 6)
# 132      0.4        (8, 10, 5, 7)
# 133      0.2        (8, 10, 6, 7)
# 134      0.2      (1, 3, 4, 5, 8)
# 135      0.2     (1, 5, 6, 9, 10)
# 136      0.2      (2, 3, 5, 7, 8)
# 137      0.2     (2, 3, 5, 7, 10)
# 138      0.2     (2, 3, 5, 8, 10)
# 139      0.2     (2, 3, 7, 8, 10)
# 140      0.2     (2, 5, 7, 8, 10)
# 141      0.2      (3, 5, 6, 7, 8)
# 142      0.2     (3, 5, 6, 7, 10)
# 143      0.2     (3, 5, 6, 8, 10)
# 144      0.4     (3, 5, 7, 8, 10)
# 145      0.2     (3, 6, 7, 8, 10)
# 146      0.2     (5, 6, 7, 8, 10)
# 147      0.2  (2, 3, 5, 7, 8, 10)
# 148      0.2  (3, 5, 6, 7, 8, 10)
# Itemset: frozenset({5}). Support: 1.0.

# %% [markdown]
# Conveniently, if the parameter ``use_colnames`` is set to ``True``,  the ``mlxtend`` function ``apriori`` may instead return a ``DataFrame`` that represents itemsets by ``frozensets`` of item names.

# %%
pd.set_option('display.max_rows', 500)

frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)
display(frequent_itemsets)
# Out:
#      support                                           itemsets
# 0        0.2                                            (Apple)
# 1        0.4                                             (Corn)
# 2        0.2                                             (Dill)
# 3        0.8                                             (Eggs)
# 4        0.2                                        (Ice cream)
# 5        1.0                                     (Kidney Beans)
# 6        0.6                                             (Milk)
# 7        0.4                                           (Nutmeg)
# 8        0.6                                            (Onion)
# 9        0.2                                          (Unicorn)
# 10       0.6                                           (Yogurt)
# 11       0.2                                      (Apple, Eggs)
# 12       0.2                              (Apple, Kidney Beans)
# 13       0.2                                      (Apple, Milk)
# 14       0.2                                       (Corn, Eggs)
# 15       0.2                                  (Corn, Ice cream)
# 16       0.4                               (Corn, Kidney Beans)
# 17       0.2                                       (Corn, Milk)
# 18       0.2                                      (Corn, Onion)
# 19       0.2                                    (Corn, Unicorn)
# 20       0.2                                     (Corn, Yogurt)
# 21       0.2                                       (Eggs, Dill)
# 22       0.2                               (Kidney Beans, Dill)
# 23       0.2                                     (Nutmeg, Dill)
# 24       0.2                                      (Onion, Dill)
# 25       0.2                                     (Yogurt, Dill)
# 26       0.2                                  (Ice cream, Eggs)
# 27       0.8                               (Kidney Beans, Eggs)
# 28       0.4                                       (Milk, Eggs)
# 29       0.4                                     (Nutmeg, Eggs)
# 30       0.6                                      (Onion, Eggs)
# 31       0.4                                     (Yogurt, Eggs)
# 32       0.2                          (Ice cream, Kidney Beans)
# 33       0.2                                 (Onion, Ice cream)
# 34       0.6                               (Milk, Kidney Beans)
# 35       0.4                             (Nutmeg, Kidney Beans)
# 36       0.6                              (Onion, Kidney Beans)
# 37       0.2                            (Unicorn, Kidney Beans)
# 38       0.6                             (Yogurt, Kidney Beans)
# 39       0.2                                     (Milk, Nutmeg)
# 40       0.2                                      (Milk, Onion)
# 41       0.2                                    (Milk, Unicorn)
# 42       0.4                                     (Yogurt, Milk)
# 43       0.4                                    (Onion, Nutmeg)
# 44       0.4                                   (Yogurt, Nutmeg)
# 45       0.4                                    (Yogurt, Onion)
# 46       0.2                                  (Yogurt, Unicorn)
# 47       0.2                        (Kidney Beans, Apple, Eggs)
# 48       0.2                                (Apple, Milk, Eggs)
# 49       0.2                        (Apple, Milk, Kidney Beans)
# 50       0.2                            (Corn, Ice cream, Eggs)
# 51       0.2                         (Kidney Beans, Corn, Eggs)
# 52       0.2                                (Corn, Onion, Eggs)
# 53       0.2                    (Corn, Ice cream, Kidney Beans)
# 54       0.2                           (Corn, Onion, Ice cream)
# 55       0.2                         (Corn, Milk, Kidney Beans)
# 56       0.2                        (Corn, Onion, Kidney Beans)
# 57       0.2                      (Corn, Unicorn, Kidney Beans)
# 58       0.2                       (Corn, Yogurt, Kidney Beans)
# 59       0.2                              (Corn, Milk, Unicorn)
# 60       0.2                               (Corn, Yogurt, Milk)
# 61       0.2                            (Corn, Yogurt, Unicorn)
# 62       0.2                         (Kidney Beans, Eggs, Dill)
# 63       0.2                               (Eggs, Nutmeg, Dill)
# 64       0.2                                (Eggs, Onion, Dill)
# 65       0.2                               (Eggs, Yogurt, Dill)
# 66       0.2                       (Kidney Beans, Nutmeg, Dill)
# 67       0.2                        (Kidney Beans, Onion, Dill)
# 68       0.2                       (Kidney Beans, Yogurt, Dill)
# 69       0.2                              (Onion, Nutmeg, Dill)
# 70       0.2                             (Yogurt, Nutmeg, Dill)
# 71       0.2                              (Yogurt, Onion, Dill)
# 72       0.2                    (Kidney Beans, Ice cream, Eggs)
# 73       0.2                           (Onion, Ice cream, Eggs)
# 74       0.4                         (Kidney Beans, Milk, Eggs)
# 75       0.4                       (Kidney Beans, Nutmeg, Eggs)
# 76       0.6                        (Kidney Beans, Onion, Eggs)
# 77       0.4                       (Kidney Beans, Yogurt, Eggs)
# 78       0.2                               (Milk, Nutmeg, Eggs)
# 79       0.2                                (Milk, Onion, Eggs)
# 80       0.2                               (Yogurt, Milk, Eggs)
# 81       0.4                              (Onion, Nutmeg, Eggs)
# 82       0.4                             (Yogurt, Nutmeg, Eggs)
# 83       0.4                              (Yogurt, Onion, Eggs)
# 84       0.2                   (Onion, Ice cream, Kidney Beans)
# 85       0.2                       (Milk, Nutmeg, Kidney Beans)
# 86       0.2                        (Milk, Onion, Kidney Beans)
# 87       0.2                      (Milk, Unicorn, Kidney Beans)
# 88       0.4                       (Yogurt, Milk, Kidney Beans)
# 89       0.4                      (Onion, Nutmeg, Kidney Beans)
# 90       0.4                     (Yogurt, Nutmeg, Kidney Beans)
# 91       0.4                      (Yogurt, Onion, Kidney Beans)
# 92       0.2                    (Yogurt, Unicorn, Kidney Beans)
# 93       0.2                              (Milk, Onion, Nutmeg)
# 94       0.2                             (Yogurt, Milk, Nutmeg)
# 95       0.2                              (Yogurt, Onion, Milk)
# 96       0.2                            (Yogurt, Milk, Unicorn)
# 97       0.4                            (Yogurt, Onion, Nutmeg)
# 98       0.2                  (Kidney Beans, Apple, Milk, Eggs)
# 99       0.2              (Kidney Beans, Corn, Ice cream, Eggs)
# 100      0.2                     (Corn, Onion, Ice cream, Eggs)
# 101      0.2                  (Kidney Beans, Corn, Onion, Eggs)
# 102      0.2             (Corn, Onion, Ice cream, Kidney Beans)
# 103      0.2                (Corn, Milk, Unicorn, Kidney Beans)
# 104      0.2                 (Corn, Yogurt, Milk, Kidney Beans)
# 105      0.2              (Corn, Yogurt, Unicorn, Kidney Beans)
# 106      0.2                      (Corn, Yogurt, Milk, Unicorn)
# 107      0.2                 (Kidney Beans, Eggs, Nutmeg, Dill)
# 108      0.2                  (Kidney Beans, Eggs, Onion, Dill)
# 109      0.2                 (Kidney Beans, Eggs, Yogurt, Dill)
# 110      0.2                        (Eggs, Onion, Nutmeg, Dill)
# 111      0.2                       (Eggs, Yogurt, Nutmeg, Dill)
# 112      0.2                        (Eggs, Yogurt, Onion, Dill)
# 113      0.2                (Kidney Beans, Onion, Nutmeg, Dill)
# 114      0.2               (Kidney Beans, Yogurt, Nutmeg, Dill)
# 115      0.2                (Kidney Beans, Yogurt, Onion, Dill)
# 116      0.2                      (Yogurt, Onion, Nutmeg, Dill)
# 117      0.2             (Kidney Beans, Onion, Ice cream, Eggs)
# 118      0.2                 (Kidney Beans, Milk, Nutmeg, Eggs)
# 119      0.2                  (Kidney Beans, Milk, Onion, Eggs)
# 120      0.2                 (Kidney Beans, Yogurt, Milk, Eggs)
# 121      0.4                (Kidney Beans, Onion, Nutmeg, Eggs)
# 122      0.4               (Kidney Beans, Yogurt, Nutmeg, Eggs)
# 123      0.4                (Kidney Beans, Yogurt, Onion, Eggs)
# 124      0.2                        (Milk, Onion, Nutmeg, Eggs)
# 125      0.2                       (Yogurt, Milk, Nutmeg, Eggs)
# 126      0.2                        (Yogurt, Onion, Milk, Eggs)
# 127      0.4                      (Yogurt, Onion, Nutmeg, Eggs)
# 128      0.2                (Milk, Onion, Nutmeg, Kidney Beans)
# 129      0.2               (Yogurt, Milk, Nutmeg, Kidney Beans)
# 130      0.2                (Yogurt, Onion, Milk, Kidney Beans)
# 131      0.2              (Yogurt, Milk, Unicorn, Kidney Beans)
# 132      0.4              (Yogurt, Onion, Nutmeg, Kidney Beans)
# 133      0.2                      (Nutmeg, Yogurt, Onion, Milk)
# 134      0.2       (Onion, Eggs, Ice cream, Kidney Beans, Corn)
# 135      0.2        (Milk, Yogurt, Unicorn, Kidney Beans, Corn)
# 136      0.2          (Onion, Eggs, Nutmeg, Dill, Kidney Beans)
# 137      0.2         (Eggs, Yogurt, Nutmeg, Dill, Kidney Beans)
# 138      0.2          (Onion, Eggs, Yogurt, Dill, Kidney Beans)
# 139      0.2                (Onion, Eggs, Yogurt, Nutmeg, Dill)
# 140      0.2        (Onion, Yogurt, Nutmeg, Dill, Kidney Beans)
# 141      0.2          (Onion, Milk, Eggs, Nutmeg, Kidney Beans)
# 142      0.2         (Milk, Eggs, Yogurt, Nutmeg, Kidney Beans)
# 143      0.2          (Onion, Milk, Eggs, Yogurt, Kidney Beans)
# 144      0.4        (Onion, Eggs, Yogurt, Nutmeg, Kidney Beans)
# 145      0.2                (Onion, Milk, Eggs, Yogurt, Nutmeg)
# 146      0.2        (Onion, Milk, Yogurt, Nutmeg, Kidney Beans)
# 147      0.2  (Onion, Eggs, Yogurt, Nutmeg, Dill, Kidney Beans)
# 148      0.2  (Onion, Milk, Eggs, Yogurt, Nutmeg, Kidney Beans)

# %% [markdown]
# Using typical ``pandas`` functionalities, it is easy to include a column in such a ``DataFrame`` to register the number of items in each frequent itemset, which can be used to filter itemsets by length.

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x)) # length of each frozenset
print('Frequent 3-itemsets:')
display(frequent_itemsets[frequent_itemsets['length'] == 3])
# Out:
# Frequent 3-itemsets:
#     support                          itemsets  length
# 47      0.2       (Kidney Beans, Apple, Eggs)       3
# 48      0.2               (Apple, Milk, Eggs)       3
# 49      0.2       (Apple, Milk, Kidney Beans)       3
# 50      0.2           (Corn, Ice cream, Eggs)       3
# 51      0.2        (Kidney Beans, Corn, Eggs)       3
# 52      0.2               (Corn, Onion, Eggs)       3
# 53      0.2   (Corn, Ice cream, Kidney Beans)       3
# 54      0.2          (Corn, Onion, Ice cream)       3
# 55      0.2        (Corn, Milk, Kidney Beans)       3
# 56      0.2       (Corn, Onion, Kidney Beans)       3
# 57      0.2     (Corn, Unicorn, Kidney Beans)       3
# 58      0.2      (Corn, Yogurt, Kidney Beans)       3
# 59      0.2             (Corn, Milk, Unicorn)       3
# 60      0.2              (Corn, Yogurt, Milk)       3
# 61      0.2           (Corn, Yogurt, Unicorn)       3
# 62      0.2        (Kidney Beans, Eggs, Dill)       3
# 63      0.2              (Eggs, Nutmeg, Dill)       3
# 64      0.2               (Eggs, Onion, Dill)       3
# 65      0.2              (Eggs, Yogurt, Dill)       3
# 66      0.2      (Kidney Beans, Nutmeg, Dill)       3
# 67      0.2       (Kidney Beans, Onion, Dill)       3
# 68      0.2      (Kidney Beans, Yogurt, Dill)       3
# 69      0.2             (Onion, Nutmeg, Dill)       3
# 70      0.2            (Yogurt, Nutmeg, Dill)       3
# 71      0.2             (Yogurt, Onion, Dill)       3
# 72      0.2   (Kidney Beans, Ice cream, Eggs)       3
# 73      0.2          (Onion, Ice cream, Eggs)       3
# 74      0.4        (Kidney Beans, Milk, Eggs)       3
# 75      0.4      (Kidney Beans, Nutmeg, Eggs)       3
# 76      0.6       (Kidney Beans, Onion, Eggs)       3
# 77      0.4      (Kidney Beans, Yogurt, Eggs)       3
# 78      0.2              (Milk, Nutmeg, Eggs)       3
# 79      0.2               (Milk, Onion, Eggs)       3
# 80      0.2              (Yogurt, Milk, Eggs)       3
# 81      0.4             (Onion, Nutmeg, Eggs)       3
# 82      0.4            (Yogurt, Nutmeg, Eggs)       3
# 83      0.4             (Yogurt, Onion, Eggs)       3
# 84      0.2  (Onion, Ice cream, Kidney Beans)       3
# 85      0.2      (Milk, Nutmeg, Kidney Beans)       3
# 86      0.2       (Milk, Onion, Kidney Beans)       3
# 87      0.2     (Milk, Unicorn, Kidney Beans)       3
# 88      0.4      (Yogurt, Milk, Kidney Beans)       3
# 89      0.4     (Onion, Nutmeg, Kidney Beans)       3
# 90      0.4    (Yogurt, Nutmeg, Kidney Beans)       3
# 91      0.4     (Yogurt, Onion, Kidney Beans)       3
# 92      0.2   (Yogurt, Unicorn, Kidney Beans)       3
# 93      0.2             (Milk, Onion, Nutmeg)       3
# 94      0.2            (Yogurt, Milk, Nutmeg)       3
# 95      0.2             (Yogurt, Onion, Milk)       3
# 96      0.2           (Yogurt, Milk, Unicorn)       3
# 97      0.4           (Yogurt, Onion, Nutmeg)       3

# %% [markdown]
# It is also easy to create a ``dict`` that maps any frequent itemset (represented by a ``frozenset``) to its support.

# %%
support = {}
for _, row in frequent_itemsets.iterrows():
    support[row['itemsets']] = row['support']

itemset = frozenset(['Onion', 'Eggs'])
print('Itemset: {0}. Support: {1}.'.format(itemset, support[itemset]))
# Out:
# Itemset: frozenset({'Onion', 'Eggs'}). Support: 0.6.

# %% [markdown]
# ## 2. Association rules

# %% [markdown]
# The ``mlxtend`` function ``association_rules`` receives a ``DataFrame`` that represents the set of frequent itemsets and returns a ``DataFrame`` that represents strong association rules for a specified confidence threshold. Each row in the resulting  ``DataFrame`` contains an association rule together with some potentially useful measures (we have not covered lift, leverage, or conviction).

# %%
from mlxtend.frequent_patterns import association_rules

strong_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
display(strong_rules)
# Out:
#               antecedents            consequents  ...  leverage  conviction
# 0          (Kidney Beans)                 (Eggs)  ...      0.00         1.0
# 1                  (Eggs)         (Kidney Beans)  ...      0.00         inf
# 2                 (Onion)                 (Eggs)  ...      0.12         inf
# 3                  (Eggs)                (Onion)  ...      0.12         1.6
# 4                  (Milk)         (Kidney Beans)  ...      0.00         inf
# 5                 (Onion)         (Kidney Beans)  ...      0.00         inf
# 6                (Yogurt)         (Kidney Beans)  ...      0.00         inf
# 7   (Onion, Kidney Beans)                 (Eggs)  ...      0.12         inf
# 8    (Eggs, Kidney Beans)                (Onion)  ...      0.12         1.6
# 9           (Onion, Eggs)         (Kidney Beans)  ...      0.00         inf
# 10                (Onion)   (Eggs, Kidney Beans)  ...      0.12         inf
# 11                 (Eggs)  (Onion, Kidney Beans)  ...      0.12         1.6
#
# [12 rows x 9 columns]

# %% [markdown]
# ## Assignment 3 [Part 2/2]
#
# 1. What is the advantage of using the Apriori algorithm in comparison with computing the support of every subset of an itemset in order to find the frequent itemsets in a transaction dataset? [0.5/5]
# 2. Let $\mathcal{L}_1$ denote the set of frequent $1$-itemsets. For $k \geq 2$, why must every frequent $k$-itemset be a superset of an itemset in $\mathcal{L}_1$? [0.5/5]
# 3. Let $\mathcal{L}_2 = \{ \{1,2\}, \{1,5\}, \{2, 3\}, \{3, 4\}, \{3, 5\}\}$. Compute the set of candidates $\mathcal{C}_3$ that is obtained by joining every pair of joinable itemsets from $\mathcal{L}_2$. [0.5/5]
# 4. Let $S_1$ denote the support of the association rule $\{ \text{popcorn, soda} \} \Rightarrow \{ \text{movie} \}$. Let $S_2$ denote the support of the association rule $\{ \text{popcorn} \} \Rightarrow \{ \text{movie} \}$. What is the relationship between $S_1$ and $S_2$? [0.5/5]
# 5. What is the support of the rule $\{  \} \Rightarrow \{ \text{Kidney Beans} \}$ in the transaction dataset used in the tutorial presented above? [0.5/5]
# 6. In the transaction dataset used in the tutorial presented above, what is the maximum length of a frequent itemset for a support threshold of 0.2? [0.5/5]
# 7. Implement a function that receives a ``DataFrame`` of frequent itemsets and a **strong** association rule (represented by a ``frozenset`` of antecedents and a ``frozenset`` of consequents). This function should return the corresponding Kulczynski measure. Include the code in your report. [1/5]
# 8. Implement a function that receives a ``DataFrame`` of frequent itemsets and a **strong** association rule (represented by a ``frozenset`` of antecedents and a ``frozenset`` of consequents). This function should return the corresponding imbalance ratio. Include the code in your report. [1/5]
