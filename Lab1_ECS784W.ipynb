# %% [markdown]
# # 1. Basic data types

# %% [markdown]
# Variable are dynamically typed, i.e. no need to explicitly declare the type
#
# E.g. In the python interactive shell

# %%
a=1

# %%
type(a) #output <class‘int'>
# Out:
# int

# %%
b=1.0

# %%
type(b)  #output <class 'float'>
# Out:
# float

# %%
x=True

# %%
type(x) #output <class 'bool'>
# Out:
# bool

# %%
name="Adam"

# %%
type(name) #output <class 'str'>
# Out:
# str

# %% [markdown]
# The dynamic type in Python makes it quite convenient for data analytics

# %% [markdown]
# # 2. Operators

# %% [markdown]
# ## Arithmetic (+,-,*,/, %)

# %%
a=10
b=40

# %%
a+b
# Out:
# 14

# %%
a-b
# Out:
# -30

# %%
a*b
# Out:
# 400

# %%
a/b   #be carefull about the division 0
# Out:
# 0.25

# %%
a%b   #module operation, returns the remainder
# Out:
# 10

# %% [markdown]
# ## Relational/Comparision(>, <, >=, <=, ==, !=)

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a == b  # True if a is equal to b else False
# Out:
# False

# %%
a != b # True if a is not equal to b else False
# Out:
# True

# %% [markdown]
# ## An interesting comparison

# %%
c = 0
d = 0.0

# %%
c == d
# Out:
# True

# %%
c != d
# Out:
# False

# %% [markdown]
# Python can deal with integer and float comparison automatically (not always!)

# %% [markdown]
# # 3. Operators continue ....

# %% [markdown]
# ## Logical ( and, or, not)

# %%
a = 10; b=4; c=2

# %%
a > b and a > c #True if a is greater than b and c else False
# Out:
# True

# %%
a > b or a > c #True if a is greater than b or c else False
# Out:
# True

# %%
not a > b      #True if a lesser than b else False
# Out:
# False

# %% [markdown]
# # Return to slides

# %% [markdown]
# # 4. Decision making and looping

# %% [markdown]
# ## if elif else

# %%
marks = 59

# %%
if marks >= 70:
    print('1st class')
elif marks >= 40:
    print('Passed')
else:
    print('Failed')
# Out:
# Passed

# %% [markdown]
# In Python 2.7, just use print ' ' No parenthesis for print in 2.7

# %% [markdown]
# ## for loop

# %%
data =  [1, 2, 3, 4, 5]

# %%
sum = 0

# %%
for item in data: 
    sum += item

#loops ends here
print(sum)
# Out:
# 15

# %% [markdown]
# Note: sum += item is short-hand notation of writing sum = sum + item

# %% [markdown]
# An alternative way: sum(data)

# %% [markdown]
# ## While loop

# %%
data = [1,2,3,4,5]
n = len(data)
i= 0 
sum = 0
# Out:
# 3

# %%
while i < n:
    sum += data[i]
    i += 1
#loop ends here
print(sum)
# Out:
# 15

# %% [markdown]
# # Return to slides

# %% [markdown]
# # 5. Function

# %% [markdown]
# We can write our own functions using the keyboard 'def' General syntax:
#
# def <span style="color:blue">function_name</span>(parameters):
#
#     body of the function
#
#     return sth
#
# Example: finding the sum of elements in a list using for loop

# %%
def sum_list(data):
    """ Returns the sum of a list of numbers""" #Good habit to add comments
    sum = 0
    for x in data:
        sum+=x
    return sum

# %%
#Using the above function
result = sum_list([1,2,3,4])
print(result)
# Out:
# 10

# %% [markdown]
# # 6. Functions: returning multiple values

# %%
def max_min(data):
    """ Returns min, max from the list"""
    min, max = data[0], data[0]
    for item in data:
        if item < min:
            min = item
        elif item > max:
            max = item
    return max, min
#This function returns two valus that will be returned as a tuple
#Usage:

# %%
max, min = max_min([1,7,2,9,12])
#print('Max is '+ max+ ' and min is ' + min)
# Out:
# (12, 2)

# %%
print('Max is '+ str(max)+ ' and min is ' + str(min))
# Out:
# Max is 12 and min is 1

# %% [markdown]
# # 7. Functions: named and default parameters

# %% [markdown]
# ### In function call, parameters can be explicitly named and we can initialize them with default values
# ### Default and named parameters can also be conveniently combined

# %%
# Named parameters

# %%
def compute_sum(a,b):
    return a + b
#Usages:
ans = compute_sum(10, 20)
ans = compute_sum(b=20, a=10)

# %%
# Named + default parameters
def compute_sum(a, b, addC=False, c=99):
    if addC:
        return a + b + c
    else:
        return a + b
#Usage:
ans = compute_sum(10, 20, True)

# %%
ans = compute_sum(a=10, b=20, True, 200) 
# be careful about the order of parameters to avoid ambiguilty
# Out:
#   File "<ipython-input-67-d7a556a59053>", line 1
#     ans = compute_sum(a=0, 20, True, 200)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
ans = compute_sum(20, 10, True, 200)

# %% [markdown]
# # Return to slide

# %% [markdown]
# # 8. Compound types

# %% [markdown]
# ## Strings
# ## Lists
# ## Tuples
# ## Dictionaries

# %% [markdown]
# # 9. Strings

# %% [markdown]
# ## Functionalities associated with strings are defined in 'str' class'

# %%
hello = 'hello' # String literals can use single quotes

# %%
hello = "hello" # double quotes are also ok

# %%
print(hello)    # Print string
# Out:
# hello

# %%
print(len(hello)) # Print length of string
# Out:
# 5

# %%
world = 'world'
msg = hello + " " + world # String concatenation
print(msg)
# Out:
# hello world

# %%
print('%s %s %d' % (hello, world, 2020)) # Positional argument
# Out:
# hello world 2020

# %%
# Note: statements starting with # symbol are treated as comments 
# and are not running during execution

# %% [markdown]
# # 10. String methods

# %%
s = 'hello'

# %%
print(s.capitalize())
# Out:
# Hello

# %%
print(s.upper())
# Out:
# HELLO

# %%
print(s.rjust(7)) # Right justify a string, padding with spaces
# Out:
#   hello

# %%
print(s.center(7)) # Center a string, padding with spaces
# Out:
#  hello

# %%
print(s.replace('l', '(ell)')) #Replace 'l' with '(ell)'
# Out:
# he(ell)(ell)o

# %%
print(' world '.strip()) #Strip leading and trailing whitespace
# Out:
# world

# %%
## Python has rstrip and lstrip functions aslo!!

# %%
print(' world '.lstrip()) # remove left white space
# Out:
# world

# %%
print(' world '.rstrip()) # remove right white space
# Out:
#  world

# %% [markdown]
# # 11. String methods: find, split

# %%
smiles = 'C(=N)(N)N.C(=O)(O)O'

# %%
smiles.find("(O)")
# Out:
# 15

# %%
smiles.find("1") # returns -1 if it couldn't find a match
# Out:
# -1

# %%
smiles.split(".") #split the strings into a list
# Out:
# ['C(=N)(N)N', 'C(=O)(O)O']

# %% [markdown]
# # 12. String operators: in, not in

# %%
if 'Br' in 'Brother':
    print('contains brother')
# Out:
# contains brother

# %%
email_address = 'yn'
if '@' not in email_address:
    email_address += '@qmul.ac.uk'
print(email_address)
# Out:
# yn@qmul.ac.uk

# %% [markdown]
# # 13. Lists

# %% [markdown]
# ## A list is a compound data type that is resizable and can contain elements of different types

# %%
x = [5,6,8] #Create a list

# %%
print(x, x[2])
# Out:
# [5, 6, 8] 8

# %%
print(x[-1]) # Print the last element negative index counts from the last
# Out:
# 8

# %%
x[2] = 'hello' #Change the third element

# %%
x
# Out:
# [5, 6, 'hello']

# %%
x.append('qmul') #Add new element in the end

# %%
print(x)
# Out:
# [5, 6, 'hello', 'qmul']

# %%
y = x.pop() # Remove and return the last element

# %%
print(y)
# Out:
# qmul

# %%
print(y, x)
# Out:
# qmul [5, 6, 'hello']

# %%
print(len(x)) #Gives the length of the lists
# Out:
# 3

# %% [markdown]
# ##  More documentations can be found in the Python official site

# %% [markdown]
# # 14. Handy list functions

# %% [markdown]
# ## append, count, extend, index, insert, pop, remove, reverse, sort

# %%
days = ['Mon','Tue', 'Wed', 'Thu', 'Fri']
days.reverse()

# %%
print(days)
# Out:
# ['Fri', 'Thu', 'Wed', 'Tue', 'Mon']

# %%
x = [1,2,3,4]
x.extend([5,6,7])

# %%
print(x)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
x = 'Let us go then, you and I'
x=list('prasanna gnanavel')
#x
# Out:
# ['p',
#  'r',
#  'a',
#  's',
#  'a',
#  'n',
#  'n',
#  'a',
#  ' ',
#  'g',
#  'n',
#  'a',
#  'n',
#  'a',
#  'v',
#  'e',
#  'l']

# %%
x.count('e') # return the number of times
# Out:
# 1

# %%
x.count(' ')
# Out:
# 6

# %% [markdown]
# # 15. Slicing operations

# %% [markdown]
# ## Simple mechanism to access a sub-lists from a given lists

# %%
nums = list(range(5)) # range is a build-in function that creates a list of integers

# %%
print(nums)
# Out:
# [0, 1, 2, 3, 4]

# %%
print(nums[2:4])
# Out:
# [2, 3]

# %%
print(nums[2:])
# Out:
# [2, 3, 4]

# %%
print(nums[:2])
# Out:
# [0, 1]

# %%
print(nums[:])
# Out:
# [0, 1, 2, 3, 4]

# %%
print(nums[:-1])
# Out:
# [0, 1, 2, 3]

# %%
print(nums[:-2])
# Out:
# [0, 1, 2]

# %%
nums = list(range(5))
print(nums)
nums[2:4] = [8,19]
print(nums)
# Out:
# [0, 1, 2, 3, 4]
# [0, 1, 8, 19, 4]

# %%
print(nums)
# Out:
# [0, 1, 8, 19, 9, 3, 4]

# %% [markdown]
# ## This operations is also supported in Numpy and faster for large arrays

# %% [markdown]
# # 16. Looping in lists

# %%
names = ['John', 'Mickey', 'David']
for name in names:
    print(name)
# Out:
# John
# Mickey
# David

# %% [markdown]
# # 17. List comprehension

# %%
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# ## 18. Using list comprehension (compact form)

# %%
squares = [x**2 for x in nums]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# ## 19. List comprehension with conditions

# %%
even_squares = [x**2 for x in nums if x%2==0]

# %%
print(even_squares)
# Out:
# [0, 4, 16]

# %% [markdown]
# # 20. Tuples

# %% [markdown]
# ## Tuples are immutable, once created, they cannot be modified

# %%
x = (1, 2,8)
type(x)
# Out:
# tuple

# %%
x = 1, 2

# %%
type(x)
# Out:
# tuple

# %%
print(x[0])
# Out:
# 1

# %%
x[0] = 5  #cannot be modified
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-1053a2668c21> in <module>
# ----> 1 x[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
pos = (10, 20, 30)

# %%
(x,y,z) = pos
pos1 = (10, 20, 30)
pos2 = (10, 25, 30)
pos1 == pos2  #True if each element is equal
# Out:
# False

# %%
x, y = 10, 15
x, y = y, x #can swap variables with a single line

# %%
print(x, y)
# Out:
# 15 10

# %% [markdown]
# # 21. Dictionaries

# %% [markdown]
# ## A dictionary maps from a unique key to a value. Duplicate keys are not allowed.
# ## Duplicated values are fine

# %%
office = {'Dan':104, 'John':146, 'Chris':124}

# %%
type(office)
# Out:
# dict

# %%
office['Dan']  #Loop up a value given a key
# Out:
# 104

# %%
## Operations with dictionaries

# %%
office['John'] = 282

# %%
print(office)
# Out:
# {'Dan': 104, 'John': 282, 'Chris': 124}

# %%
office.keys() #return the lists of keys
# Out:
# dict_keys(['Dan', 'John', 'Chris'])

# %%
office.has_key('Jose') # check if key exists
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-c2d8c4c736e7> in <module>
# ----> 1 office.has_key('Jose')
#
# AttributeError: 'dict' object has no attribute 'has_key'

# %%
del office['John']

# %%
print('John' in office)
# Out:
# False

# %% [markdown]
# # 22. Loop in dictionary

# %%
d = {'person':2, 'cat':4, 'spider':8}

# %%
for animal in d:
    legs = d[animal]
    print('A %s has %d legs' %(animal, legs) )
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
## If you want to access keys and their corresponding values,
## use the item method

# %%
for animal, legs in d.items():
    print('A %s has %d legs' %(animal, legs) )
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %% [markdown]
# # 23. Dictionary comprehension

# %% [markdown]
# ## These are similar to list comprehensions, but allows you to contruct dictionaries easily

# %%
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x**2 for x in nums}

# %%
print(even_num_to_square)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# # 24. File reading/writing

# %% [markdown]
# ## General syntax:

# %% [markdown]
# ### <span style="color:blue">f = open(filename, 'mode')</style>

# %% [markdown]
# ## Example

# %%
input_file = open('input.txt', 'r')
output_file = open('test.txt', 'w') 
for line in input_file:
    output_file.write(line)
    print(line)
input_file.close()
output_file.close()
# Out:
# sdfdf
#
# sdfsdf

# %% [markdown]
# ## 'w' = 'writing mode'
# ## 'a' = 'append mode'
# ## 'wb' = 'write in binary'
# ## 'r' = 'read mode' (default)
# ## 'rb' = 'read in binary

# %% [markdown]
# ### <span style="color:blue">Remember to close the file in the end</style>

# %% [markdown]
# ## Return to PPT

# %%
class Message(object):
    #Constructor
    def __init__(self, message):
        self.msg = message
    
    #Instance method 
    def display(self):
        print('%s' % self.msg)

# %%
m = Message('Welcome all')
m.display()
# Out:
# Welcome all
