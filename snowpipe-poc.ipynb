# %%
import requests
import json

# %%
pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 62.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.9 MB/s eta 0:00:00
# ...

# %%
#import Boto3 library to upload the joson file to AWS S3
import boto3

# %%
url="https://data.police.uk/api/crimes-street/all-crime?lat=52.629729&lng=-1.131592&date=2023-01"

response = requests.get(url)
data = response.json()

with open('uk_crime_data2.json','w') as f:
  json.dump(data,f)

#AWS S3 configuration
aws_access_key_id="AKIAT4M4M4CVVDQQFSQN"
aws_secret_access_key="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"
bucket_name="s3bucket-prsspoc"

#create an s3 client
s3=boto3.client('s3',aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

#upload the json file to s3
s3.upload_file('uk_crime_data2.json',bucket_name,'uk_crime_data2.json')

# %%
#to delete the files in the bucket 
s3 = boto3.resource('s3',aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)
s3.Object(bucket_name, 'uk_crime_data2.json').delete()
# Out:
# {'ResponseMetadata': {'RequestId': 'B7WX3D149M5HG01S',
#   'HostId': 'rSfXDKyt/T6A710igkiX5RDcOnl+AKULHxRdH00HnFRJqpRq8SWyrMQabZGIUfg9ANl4f56veGU=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'rSfXDKyt/T6A710igkiX5RDcOnl+AKULHxRdH00HnFRJqpRq8SWyrMQabZGIUfg9ANl4f56veGU=',
#    'x-amz-request-id': 'B7WX3D149M5HG01S',
#    'date': 'Fri, 12 May 2023 21:54:18 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1}}
